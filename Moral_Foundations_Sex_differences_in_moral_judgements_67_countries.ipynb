# %% [markdown]
# <a href="https://colab.research.google.com/github/falahamro/Moral-Foundations-Analysis/blob/main/Moral_Foundations_Sex_differences_in_moral_judgements_67_countries.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df1 = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/Moral Foundations Application/Sex differences in moral judgements - 67 countries/Data_S1_sec.csv")

# %%
df2 = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/Moral Foundations Application/Sex differences in moral judgements - 67 countries/Data_S2_sec.csv")

# %%
df3 = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/Moral Foundations Application/Sex differences in moral judgements - 67 countries/ALL_MFQ30.csv")

# %%
df1
# Out:
#                  Country  PopSexRatio  Individualism  Masculinity  \
# 0            Afghanistan         1.03            NaN          NaN
# 1                Albania         0.98           20.0         80.0
# 2              Argentina         0.98           46.0         56.0
# 3              Australia         1.01           90.0         61.0
# 4                Austria         0.96           55.0         79.0
# ..                   ...          ...            ...          ...
# 62  United Arab Emirates         2.18           25.0         50.0
# 63        United Kingdom         0.99           89.0         66.0
# 64                   USA         0.97           91.0         62.0
# 65             Venezuela         0.99           12.0         73.0
# 66               Vietnam         1.00           20.0         40.0
#
#     GenderEqality  HumanDevelopmentIndex  OverallLifeSatisfactionIndex  \
# 0           0.667                  0.479                           3.1
# ...

# %%
df2
# Out:
#         Country  HARM.Cohen.d  FAIRNESS.Cohen.d  INGROUP.Cohen.d  \
# 0     Australia      0.428492          0.229754        -0.166414
# 1       Belgium      0.450297          0.197111        -0.198812
# 2         China      0.260490          0.174548         0.004004
# 3        France      0.277311          0.071702         0.011008
# 4       Hungary      0.531953          0.359322        -0.125992
# 5          Iran      0.254758          0.170536         0.030931
# 6         Japan      0.085172         -0.022846        -0.231444
# 7         Korea      0.214736          0.130202        -0.148776
# 8        Latvia      0.457871          0.526488         0.045332
# 9      Mongolia      0.137419          0.118591         0.100325
# 10  Netherlands      0.452086          0.145524        -0.219044
# 11       Poland      0.651036          0.299570        -0.001791
# 12       Russia      0.697519          0.426028        -0.061745
# ...

# %%
df3
# Out:
#        HARM_AVG  FAIRNESS_AVG  INGROUP_AVG  AUTHORITY_AVG  PURITY_AVG Sex  \
# 0      0.000000      0.000000     0.000000       0.000000    0.000000   1
# 1      4.000000      4.166667     3.000000       3.833333    2.833333   0
# 2      3.166667      4.500000     1.333333       1.166667    1.000000   1
# 3      3.000000      3.500000     3.333333       3.000000    1.500000   0
# 4      4.666667      3.666667     3.333333       3.333333    1.833333   0
# ...         ...           ...          ...            ...         ...  ..
# 11964  5.000000      4.000000     4.333333       3.500000    3.000000   0
# 11965  4.333333      4.833333     2.166667       2.500000    1.000000   1
# 11966  3.333333      2.833333     1.000000       1.666667    0.833333   0
# 11967  3.500000      3.500000     3.500000       3.833333    4.666667   0
# 11968  3.500000      4.000000     1.500000       2.333333    0.333333   1
#
#          Country
# 0      Australia
# 1      Australia
# 2      Australia
# ...

# %%
df3.Country.unique()
# Out:
# array(['Australia', 'Japan', 'Belgium', 'Netherlands', 'China', 'France',
#        'Hungary', 'Iran', 'Korea', 'Latvia', 'Mongolia', 'Poland',
#        'Russia', 'Serbia', 'Spain', 'Sweden', 'Turkey', 'UK', 'US'],
#       dtype=object)
